# %%
import xarray as xr
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12,7)

# %%
ls ../data
# Out:
# COVID-19/  humidity.nc  README.md

# %%
rh = xr.open_dataset("../data/humidity.nc").sel(expver=5)

# %%
rh['q'].isel(time=-1).plot()

# %%
# Out:
# OrderedDict([('Conventions', 'CF-1.6'),
#              ('history',
#               '2020-03-23 11:24:14 GMT by grib_to_netcdf-2.16.0: /opt/ecmwf/eccodes/bin/grib_to_netcdf -S param -o /cache/data7/adaptor.mars.internal-1584961278.847917-31455-23-613bda6d-251f-44d1-a7d0-2d645ffd8196.nc /cache/tmp/613bda6d-251f-44d1-a7d0-2d645ffd8196-adaptor.mars.internal-1584961278.8484163-31455-6-tmp.grib')])
