# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.figsize'] = (15,8)

import pandas as pd
import os
import numpy as np
from scipy.optimize import curve_fit

# Utility functions for stream-lining analysis
from utils import *

# %% [markdown]
# ## Part 1: Calculating growth rates

# %%
df = load_jhu_df()
df.head()
# Out:
#   Province/State  Country/Region    Last Update  Confirmed  Deaths  Recovered  \
# 0          Hubei  Mainland China  1/24/20 17:00      549.0    24.0       31.0
# 1      Guangdong  Mainland China  1/24/20 17:00       53.0     NaN        2.0
# 2       Zhejiang  Mainland China  1/24/20 17:00       43.0     NaN        1.0
# 3        Beijing  Mainland China  1/24/20 17:00       36.0     NaN        1.0
# 4      Chongqing  Mainland China  1/24/20 17:00       27.0     NaN        NaN
#
#          date  Latitude  Longitude
# 0  01-24-2020       NaN        NaN
# 1  01-24-2020       NaN        NaN
# 2  01-24-2020       NaN        NaN
# 3  01-24-2020       NaN        NaN
# 4  01-24-2020       NaN        NaN

# %%
plt.figure(figsize=(8,5))
global_df = df.groupby('date').sum()
global_df['Deaths'].plot(x="date")
plt.ylabel("Global deaths")
# Out:
# Text(0, 0.5, 'Global deaths')

# %% [markdown]
# ### Example: exponential growth in the U.S.
#
# We consider the growth rate of convirmed infections, starting after the 100th case in a Country/Region to avoid poor statistics of small numbers.

# %%
rdf = df.groupby(["Country/Region", "date"]).sum()
rdf_mean = df.groupby(["Country/Region"]).mean()

y, date = growth_period(rdf, 'US')
x = np.arange(0, len(y))

popt, pcov = curve_fit(func, x, y)
yfit = func(x, *popt)

plt.figure(figsize=(8,6))
y.plot(marker='o', label="Confirmed U.S. Infections")
plt.plot(x, yfit, label="Exponential fit")
plt.legend()

# %%
all_regions = df['Country/Region'].unique()

growth_rates = []
regions = []
lats = []
lons = []
start_dates = []
end_dates = []

for region in all_regions:
    y, date = growth_period(rdf, region)
    if y is None:
        print(f"Skip {region} where N < 7")
        continue
    elif len(y) < 7:
        print(f"Skip {region} where N < 7")
        continue

    x = np.arange(0, len(y))
    
    try:
        popt, pcov = curve_fit(func, x, y, p0=[100, 0.2, -50])
    except:
        print(f"Could not fit for {region}.")
    
    growth_rates.append(popt[1])
    regions.append(region)
    lats.append(rdf_mean.loc[region]['Latitude'])
    lons.append(rdf_mean.loc[region]['Longitude'])
    start_dates.append(date[0])
    end_dates.append(date[1])
    
    print(f"Computed growth rate {popt[1]} for {region}.")
    
gdf = pd.DataFrame({
    'Country/Region': regions,
    'Growth Rate':growth_rates,
    'Latitude':lats,
    'Longitude':lons,
    'Start day':pd.to_datetime(start_dates),
    'End day':pd.to_datetime(end_dates)
})
# Out:
# Computed growth rate 0.19253976414051777 for Mainland China.
# Skip Taiwan where N < 7
# Computed growth rate 0.11158800774499482 for Hong Kong.
# Skip Macau where N < 7
# Computed growth rate 0.248851993063108 for US.
# Computed growth rate 0.045556014171384523 for Japan.
# Computed growth rate 0.3694999849516071 for Thailand.
# Computed growth rate 0.13417084916427208 for South Korea.
# Computed growth rate 0.11290455984108291 for Singapore.
# Skip Vietnam where N < 7
# Computed growth rate 0.228531925913284 for France.
# Could not fit for Others.
# Computed growth rate 0.228531925913284 for Others.
# Computed growth rate 0.10805252177607151 for Malaysia.
# Computed growth rate 0.1913202083036326 for Italy.
# Computed growth rate 0.12668994496852196 for Iran.
# Computed growth rate 0.29991080755971783 for Germany.
# Skip UK where N < 7
# Skip United Arab Emirates where N < 7
# Computed growth rate 0.1948732766899728 for Canada.
# Computed growth rate 0.2187546912193049 for Australia.
# Computed growth rate 0.32716492144643866 for India.
# Computed growth rate 0.27150324064583253 for Philippines.
# Skip Russia where N < 7
# Computed growth rate 0.30599121999026746 for Spain.
# Computed growth rate 0.18511460596074839 for Belgium.
# Skip Cambodia where N < 7
# Could not fit for Egypt.
# Computed growth rate 0.18511460596074839 for Egypt.
# Computed growth rate 0.15367091084944512 for Finland.
# Computed growth rate 0.20760295975796225 for Israel.
# Computed growth rate 0.3581279484943039 for Lebanon.
# Skip Nepal where N < 7
# Skip Sri Lanka where N < 7
# Computed growth rate 0.020078344128048934 for Sweden.
# Computed growth rate 0.03954595411324955 for Bahrain.
# Computed growth rate 0.08154703513030134 for Kuwait.
# Computed growth rate 0.1666829514314849 for Austria.
# Skip Oman where N < 7
# Skip Afghanistan where N < 7
# Skip Algeria where N < 7
# Skip Croatia where N < 7
# Computed growth rate 0.046034706753429626 for Iraq.
# Computed growth rate 0.17389727060560312 for Switzerland.
# Computed growth rate 0.18566804110867166 for China.
# Could not fit for Korea, South.
# Computed growth rate 0.18566804110867166 for Korea, South.
# Computed growth rate 0.09727948159008024 for Cruise Ship.
# Computed growth rate 0.02392209057404013 for Norway.
# Computed growth rate 0.180207278063422 for Netherlands.
# Computed growth rate 0.20214237623668727 for United Kingdom.
# Could not fit for Denmark.
# Computed growth rate 0.20214237623668727 for Denmark.
# Could not fit for Qatar.
# Computed growth rate 0.20214237623668727 for Qatar.
# Computed growth rate 0.022942833108159973 for Greece.
# Computed growth rate 0.1522906887228727 for Czechia.
# Computed growth rate 0.22054830776313325 for Iceland.
# Computed growth rate 0.1836789470634508 for San Marino.
# Computed growth rate 0.23781957441769633 for Portugal.
# Computed growth rate 0.027002749625434398 for Slovenia.
# Skip Taiwan* where N < 7
# Computed growth rate 0.12562471758153573 for Romania.
# Computed growth rate 0.16100169650395887 for Ireland.
# Computed growth rate 0.38342381188618757 for Brazil.
# Computed growth rate 0.12529182146951787 for Indonesia.
# Computed growth rate 0.17332246003634083 for Poland.
# Skip Georgia where N < 7
# Computed growth rate 0.2546369164712638 for Chile.
# Computed growth rate 0.24387422813949713 for Saudi Arabia.
# Skip Argentina where N < 7
# Computed growth rate 0.07006942624953381 for Pakistan.
# Skip Ecuador where N < 7
# Could not fit for Estonia.
# Computed growth rate 0.07006942624953381 for Estonia.
# Skip Costa Rica where N < 7
# Skip Hungary where N < 7
# Skip South Africa where N < 7
# Skip Albania where N < 7
# Skip Serbia where N < 7
# Skip Azerbaijan where N < 7
# Skip Brunei where N < 7
# Skip Peru where N < 7
# Skip Latvia where N < 7
# Skip Slovakia where N < 7
# Skip Belarus where N < 7
# Skip Colombia where N < 7
# Skip Maldives where N < 7
# Skip Mexico where N < 7
# Skip Panama where N < 7
# Skip Bosnia and Herzegovina where N < 7
# Skip Bulgaria where N < 7
# Skip Luxembourg where N < 7
# Skip North Macedonia where N < 7
# Skip Tunisia where N < 7
# Skip Cyprus where N < 7
# Skip Malta where N < 7
# Skip Dominican Republic where N < 7
# Skip French Guiana where N < 7
# Skip Morocco where N < 7
# Skip New Zealand where N < 7
# Skip Paraguay where N < 7
# Skip Senegal where N < 7
# Skip Bangladesh where N < 7
# Skip Lithuania where N < 7
# Skip Martinique where N < 7
# Skip Moldova where N < 7
# Skip Bolivia where N < 7
# Skip Burkina Faso where N < 7
# Skip Cameroon where N < 7
# Skip Honduras where N < 7
# Skip Nigeria where N < 7
# Skip Andorra where N < 7
# Skip Armenia where N < 7
# Skip Bhutan where N < 7
# Skip Congo (Kinshasa) where N < 7
# Skip Cote d'Ivoire where N < 7
# Skip Holy See where N < 7
# Skip Jamaica where N < 7
# Skip Jordan where N < 7
# Skip Liechtenstein where N < 7
# Skip Monaco where N < 7
# Skip Mongolia where N < 7
# Skip Reunion where N < 7
# Skip Togo where N < 7
# Skip Turkey where N < 7
# Skip Ukraine where N < 7
# Skip occupied Palestinian territory where N < 7
# Skip Kazakhstan where N < 7
# Skip Venezuela where N < 7
# Skip Ghana where N < 7
# Skip Cuba where N < 7
# Skip Guyana where N < 7
# Skip Uruguay where N < 7
# Skip Aruba where N < 7
# Skip Jersey where N < 7
# Skip Kosovo where N < 7
# Skip Namibia where N < 7
# Skip Seychelles where N < 7
# Skip Trinidad and Tobago where N < 7
# Skip Antigua and Barbuda where N < 7
# Skip Cayman Islands where N < 7
# Skip Central African Republic where N < 7
# Skip Congo (Brazzaville) where N < 7
# Skip Curacao where N < 7
# Skip Equatorial Guinea where N < 7
# Skip Eswatini where N < 7
# Skip Ethiopia where N < 7
# Skip Gabon where N < 7
# Skip Guadeloupe where N < 7
# Skip Guatemala where N < 7
# Skip Guernsey where N < 7
# Skip Guinea where N < 7
# Skip Kenya where N < 7
# Skip Mauritania where N < 7
# Skip Rwanda where N < 7
# Skip Saint Lucia where N < 7
# Skip Saint Vincent and the Grenadines where N < 7
# Skip Sudan where N < 7
# Skip Suriname where N < 7
# Skip Uzbekistan where N < 7
# Skip Montenegro where N < 7
# Skip Mauritius where N < 7
# Skip Kyrgyzstan where N < 7
# Skip Mayotte where N < 7
# Skip Tanzania where N < 7
# Skip Barbados where N < 7
# Skip Bahamas, The where N < 7
# Skip Madagascar where N < 7
# Skip Benin where N < 7
# Skip Haiti where N < 7
# Skip Liberia where N < 7
# Skip Zambia where N < 7
# Skip Angola where N < 7
# Skip Cabo Verde where N < 7
# Skip Chad where N < 7
# Skip Djibouti where N < 7
# Skip El Salvador where N < 7
# Skip Fiji where N < 7
# Skip Gambia, The where N < 7
# Skip Nicaragua where N < 7
# Skip Niger where N < 7
# Skip Papua New Guinea where N < 7
# Skip Somalia where N < 7
# Skip Zimbabwe where N < 7
# Skip Greenland where N < 7
# Skip Guam where N < 7
# Skip Puerto Rico where N < 7
# Skip Republic of the Congo where N < 7
# Skip The Bahamas where N < 7
# Skip The Gambia where N < 7
# Skip Czech Republic where N < 7
# Skip Palestine where N < 7
# Skip Republic of Ireland where N < 7
# Skip Saint Barthelemy where N < 7
# Skip Faroe Islands where N < 7
# Skip Gibraltar where N < 7
# Skip Vatican City where N < 7
# Skip Ivory Coast where N < 7
# Skip Iran (Islamic Republic of) where N < 7
# Skip Republic of Korea where N < 7
# Skip Hong Kong SAR where N < 7
# Skip Taipei and environs where N < 7
# Skip Viet Nam where N < 7
# Skip Macao SAR where N < 7
# Skip Russian Federation where N < 7
# Skip Republic of Moldova where N < 7
# Skip Saint Martin where N < 7
# Skip Channel Islands where N < 7
# Skip St. Martin where N < 7
# Skip  Azerbaijan where N < 7
# Skip North Ireland where N < 7
# Skip Dominica where N < 7
# Skip Eritrea where N < 7
# Skip Grenada where N < 7
# Skip Mozambique where N < 7
# Skip Syria where N < 7
# Skip Timor-Leste where N < 7
# Skip Uganda where N < 7
# Skip Cape Verde where N < 7
# Skip East Timor where N < 7

# %%
gdf
# Out:
#     Country/Region  Growth Rate   Latitude   Longitude  Start day    End day
# 0   Mainland China     0.192540  33.453369  111.512734 2020-01-22 2020-02-05
# 1        Hong Kong     0.111588  22.300000  114.200000 2020-03-02 2020-03-09
# 2               US     0.248852  38.374732  -90.262391 2020-03-02 2020-03-16
# 3            Japan     0.045556  36.093091  138.114955 2020-02-21 2020-03-06
# 4         Thailand     0.369500  15.514091  100.995568 2020-03-15 2020-03-22
# 5      South Korea     0.134171  36.000000  128.000000 2020-02-20 2020-03-05
# 6        Singapore     0.112905   1.314573  103.827164 2020-02-29 2020-03-14
# 7           France     0.228532  12.401230  -21.262191 2020-02-29 2020-03-14
# 8           Others     0.228532  35.443700  139.638000 2020-02-10 2020-02-24
# 9         Malaysia     0.108053   3.277500  107.716273 2020-03-09 2020-03-22
# 10           Italy     0.191320  42.487227   12.257909 2020-02-23 2020-03-08
# 11            Iran     0.126690  32.203762   53.327619 2020-02-26 2020-03-12
# 12         Germany     0.299911  51.075318    9.659773 2020-03-01 2020-03-15
# 13          Canada     0.194873  49.646427  -92.196954 2020-03-11 2020-03-22
# 14       Australia     0.218755 -23.884840  140.672254 2020-03-10 2020-03-22
# 15           India     0.327165  20.815318   78.437682 2020-03-14 2020-03-22
# 16     Philippines     0.271503  12.928914  121.866455 2020-03-14 2020-03-22
# 17           Spain     0.305991  40.210773   -3.886000 2020-03-02 2020-03-16
# 18         Belgium     0.185115  50.683573    4.213591 2020-03-06 2020-03-20
# 19           Egypt     0.185115  26.373000   30.364773 2020-03-14 2020-03-22
# 20         Finland     0.153671  63.056409   25.885545 2020-03-13 2020-03-22
# 21          Israel     0.207603  31.020955   34.932545 2020-03-11 2020-03-22
# 22         Lebanon     0.358128  33.854700   35.862300 2020-03-15 2020-03-22
# 23          Sweden     0.020078  61.694636   17.201591 2020-03-06 2020-03-20
# 24         Bahrain     0.039546  26.045318   50.553500 2020-03-10 2020-03-22
# 25          Kuwait     0.081547  29.414409   47.628091 2020-03-14 2020-03-22
# 26         Austria     0.166683  47.516200   14.550100 2020-03-08 2020-03-22
# 27            Iraq     0.046035  33.101455   43.854227 2020-03-13 2020-03-22
# 28     Switzerland     0.173897  46.818200    8.227500 2020-03-05 2020-03-19
# 29           China     0.185668  32.746188  111.678382 2020-03-11 2020-03-22
# 30    Korea, South     0.185668  35.923167  127.805750 2020-03-11 2020-03-22
# 31     Cruise Ship     0.097279  35.448783  139.660417 2020-03-11 2020-03-22
# 32          Norway     0.023922  60.472000    8.468900 2020-03-06 2020-03-20
# 33     Netherlands     0.180207  36.454930  -24.477359 2020-03-06 2020-03-20
# 34  United Kingdom     0.202142  40.027991  -23.385699 2020-03-11 2020-03-22
# 35         Denmark     0.202142  59.666963   -1.166295 2020-03-10 2020-03-22
# 36           Qatar     0.202142  25.354800   51.183900 2020-03-11 2020-03-22
# 37          Greece     0.022943  39.074200   21.824300 2020-03-13 2020-03-22
# 38         Czechia     0.152291  49.817500   15.473000 2020-03-13 2020-03-22
# 39         Iceland     0.220548  64.963100  -19.020800 2020-03-12 2020-03-22
# 40      San Marino     0.183679  43.942400   12.457800 2020-03-15 2020-03-22
# 41        Portugal     0.237820  39.399900   -8.224500 2020-03-13 2020-03-22
# 42        Slovenia     0.027003  46.151200   14.995500 2020-03-13 2020-03-22
# 43         Romania     0.125625  45.969018   24.981891 2020-03-14 2020-03-22
# 44         Ireland     0.161002  53.154868   -7.706095 2020-03-14 2020-03-22
# 45          Brazil     0.383424 -14.235000  -51.925300 2020-03-13 2020-03-22
# 46       Indonesia     0.125292  -0.789300  113.921300 2020-03-15 2020-03-22
# 47          Poland     0.173322  51.919400   19.145100 2020-03-14 2020-03-22
# 48           Chile     0.254637 -35.675100  -71.543000 2020-03-16 2020-03-22
# 49    Saudi Arabia     0.243874  23.945667   45.037714 2020-03-14 2020-03-22
# 50        Pakistan     0.070069  30.375300   69.345100 2020-03-16 2020-03-22
# 51         Estonia     0.070069  58.595300   25.013600 2020-03-14 2020-03-22

# %% [markdown]
# ### Part 2: Calculating specific humidity

# %%
ds = xr.open_dataset("../data/thermodynamic_variables_2020.nc", chunks={'time':50})
ds['q2m'] = sat_specific_humidity(ds['d2m'], ds['sp'])
ds = ds.resample(time='1D').mean().compute()
ds.to_netcdf("../data/output/daily_spec_humidity_2020.nc")

# %%
q2m_li = []

for region in gdf['Country/Region']:
    tmp = gdf[gdf['Country/Region'] == region]
    q2m_li.append((
        ds['q2m']
        .sel(latitude=tmp['Latitude'], longitude=tmp['Longitude'], method='nearest')
        .isel(time = (
        (ds['time'] >= tmp['Start day'].values) &
        (ds['time'] < tmp['End day'].values)
        ))
    ).mean().values)
    
qdf = pd.DataFrame({'Country/Region':gdf['Country/Region'], 'Specific Humidity':q2m_li})
gqdf = pd.merge(gdf, qdf)
gqdf.to_csv("../data/output/humidity_and_growth_rates.csv")

# %%
gqdf.plot(x="Growth Rate", y="Specific Humidity", kind='scatter', figsize=(5,5))
plt.savefig("../figures/humidity_and_growth_rates.png", dpi=150, bbox_inches='tight')
