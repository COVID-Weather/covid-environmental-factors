# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/output/humidity_and_growth_rates.csv") 

df.plot(x="Growth Rate", y="Specific Humidity", kind='scatter', figsize=(5,5))
plt.savefig("../figures/humidity_and_growth_rates.png", dpi=150, bbox_inches='tight')
